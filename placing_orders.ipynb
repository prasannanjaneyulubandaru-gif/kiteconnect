# %%
import datetime
import pandas as pd

# %%
from kiteconnect import KiteConnect

# %%
# %run "C:/Users/prasannanjaneyulu.b/OneDrive - Landmark Group india/Stats_Strats/Strategies.ipynb"

# %run "C:/Users/prasannanjaneyulu.b/OneDrive - Landmark Group india/Stats_Strats/Basket_widgets.ipynb"

# %%
api_key = "kvvzk6jq4zn4o4vc"


kite = KiteConnect(api_key=api_key)

# %%
auth_url = kite.login_url()
print("Open this URL in your browser to authorize the app:")
print(auth_url)
# Out:
# Open this URL in your browser to authorize the app:
# https://kite.zerodha.com/connect/login?api_key=kvvzk6jq4zn4o4vc&v=3

# %%
access_Token = "4y6EFVR0318GiHquIpE6aPbFV5HWgeL1"

# %%
kite = KiteConnect(api_key="kvvzk6jq4zn4o4vc")
data = kite.generate_session(access_Token, api_secret="nzcqxwu05jmo2k71cmpgnbf5trz6gypn")
access_token = data["access_token"]

kite.set_access_token(access_token)

# %%
profile = kite.profile()

# Step 3: Print profile information
print("User ID:", profile["user_id"])
print("User Name:", profile["user_name"])
print("Email:", profile["email"])
print("User type:", profile["user_type"])
print("Products:", profile["products"])
print("Broker info:", profile["broker"])
# Out:
# User ID: FVC741
# User Name: Balam Baji Babu
# Email: balambajibabu143@gmail.com
# User type: individual/res_no_nn
# Products: ['CNC', 'NRML', 'MIS', 'BO', 'CO']
# Broker info: ZERODHA

# %%
instruments = kite.instruments(exchange="NFO")

# %%
# Call the function
fut_symbols, option_symbols = assume_direction(kite, instruments, lp = 40, up = 60)
# Out:
# VBox(children=(HBox(children=(Button(button_style='success', description='Bullish Strategy', style=ButtonStyle…

# %%
option_symbols
# Out:
# []

# %%
make_order_basket(fut_symbols,option_symbols, kite)
# Out:
# HBox(children=(VBox(children=(HTML(value='<h4>FUTURES</h4>'), Dropdown(description='Symbol:', layout=Layout(ma…
# HBox(children=(Button(button_style='success', description='Place All Orders', style=ButtonStyle()), Button(but…
# Output()
# Output()
